# %% [markdown]
# Today I finished setting up the Olist analytics project and successfully loaded all the dataset files into a SQLite warehouse. The data contains around 99K orders and more than 112K order item records, which already shows that many customers purchased multiple items in a single order.
#
# While checking the tables, I noticed the dataset is much more realistic than normal practice datasets because it includes customers, sellers, payments, reviews, products, and delivery information separately. I also saw that the product category names are in Portuguese, so the translation table will be useful later during analysis and dashboard building.
#
# One thing I found interesting is how closely the reviews and orders tables are connected. I want to explore whether delayed deliveries are affecting customer ratings and if certain product categories receive consistently lower reviews.
#
# Before jumping into dashboards, my next step is to carefully inspect missing values, duplicates, delivery timelines, and customer behavior patterns so the analysis feels more realistic and meaningful.

# %%
import pandas as pd
import sqlite3
from pathlib import Path
